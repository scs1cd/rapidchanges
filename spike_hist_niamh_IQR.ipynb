# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import functions_niamh as func
from scipy.stats import lognorm
from scipy.stats import norm
mpl.rcParams['agg.path.chunksize'] = 100000
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica'], 'size': 20})
rc('text', usetex=True)

# %%
#ax1.errorbar(median, y, xerr=[lower_quartile ,upper_quartile], fmt='k--')

# %%
#Run code for GGF model
tl, tu, ti, var, ntl, ntu = func.define_parameters(1)
name,adtdt,advgpdt,advdmdt,adfdt,n  = func.separate_latitudes_no_time('ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001', tl, tu, ti, var, ntl, ntu)
fig1, fig2, GGFmuX1, GGFmax1, GGFIQR1 = func.plot_figures(adtdt,advgpdt,advdmdt,adfdt,var,n, name)
GGF1muXlat, GGF1maxlat, GGF1IQR, GGF1Q1, GGF1Q3= func.IQR(adtdt,advgpdt,advdmdt,adfdt,var,n, name)
# Out:
# -77.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-77.5
# -57.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-57.5
# -37.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-37.5
# -17.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-17.5
# 2.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=2.5
# 22.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=22.5
# 42.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=42.5
# 62.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=62.5
# 82.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=82.5
# theta =  -37.5  mean = 0.009866705783795735  sigma =  0.767359467101325
# 0.18467206
# cdf =  0.9999326020094207
# theta =  -17.5  mean = 0.013622310317673261  sigma =  0.7619777241560673
# 0.26136294
# cdf =  0.9999471276600329
# theta =  2.5  mean = 0.01593905923095694  sigma =  0.7530113013062104
# 2.3793657
# cdf =  0.9999999999851177
# ...

# %%
#Run code for LSMOD.2 model
tl, tu, ti, var, ntl, ntu = func.define_parameters(1)
name,adtdt,advgpdt,advdmdt,adfdt,n  = func.separate_latitudes_no_time('LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001', tl, tu, ti, var, ntl, ntu)
fig1, fig2, LSMODmuX1, LSMODmax1, LSMODIQR1  = func.plot_figures(adtdt,advgpdt,advdmdt,adfdt,var,n, name)

LSMOD1muXlat, LSMOD1maxlat, LSMOD1IQR, LSMOD1Q1, LSMOD1Q3= func.IQR(adtdt,advgpdt,advdmdt,adfdt,var,n,name)
# Out:
# -77.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-77.5
# -57.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-57.5
# -37.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-37.5
# -17.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-17.5
# 2.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=2.5
# 22.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=22.5
# 42.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=42.5
# 62.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=62.5
# 82.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=82.5
# theta =  -37.5  mean = 0.033451760218230916  sigma =  0.9368005001740157
# 2.3950314
# cdf =  0.9999974323795632
# theta =  -17.5  mean = 0.04274650340686943  sigma =  0.9099381978584744
# 3.3062584
# cdf =  0.9999991176623421
# theta =  2.5  mean = 0.04753628879823222  sigma =  0.8502648727588302
# 2.8334936
# cdf =  0.9999992364097322
# ...

# %%
#Run code for CALS model
tl, tu, ti, var, ntl, ntu = func.define_parameters(1)
name,adtdt,advgpdt,advdmdt,adfdt,n  = func.separate_latitudes_no_time('cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001', tl, tu, ti, var, ntl, ntu)
fig1, fig2, CALSmuX1, CALSmax1, CALSIQR1 = func.plot_figures(adtdt,advgpdt,advdmdt,adfdt,var,n,name)
CALS1muXlat, CALS1maxlat, CALS1IQR, CALS1Q1, CALS1Q3= func.IQR(adtdt,advgpdt,advdmdt,adfdt,var,n, name)
# Out:
# -77.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=-77.5
# -57.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=-57.5
# -37.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=-37.5
# -17.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=-17.5
# 2.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=2.5
# 22.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=22.5
# 42.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=42.5
# 62.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=62.5
# 82.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=82.5
# theta =  -37.5  mean = 0.011484253191114065  sigma =  0.7199766246128413
# 0.058034571
# cdf =  0.9877805815844148
# theta =  -17.5  mean = 0.01608883635724245  sigma =  0.7193606100543306
# 0.074682486
# cdf =  0.9835788614943696
# theta =  2.5  mean = 0.020446884022438137  sigma =  0.7146723062345444
# 0.10182037
# cdf =  0.9876581058724085
# ...

# %%
#Run code for GGF model
tl, tu, ti, var, ntl, ntu = func.define_parameters(2)
name,adtdt,advgpdt,advdmdt,adfdt,n  = func.separate_latitudes_no_time('ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001', tl, tu, ti, var, ntl, ntu)
fig1, fig2, GGFmuX2, GGFmax2, GGFIQR2 = func.plot_figures(adtdt,advgpdt,advdmdt,adfdt,var,n,name)
GGF2muXlat, GGF2maxlat, GGF2IQR, GGF2Q1, GGF2Q3= func.IQR(adtdt,advgpdt,advdmdt,adfdt,var,n, name)
# Out:
# -77.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-77.5
# -57.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-57.5
# -37.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-37.5
# -17.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-17.5
# 2.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=2.5
# 22.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=22.5
# 42.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=42.5
# 62.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=62.5
# 82.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=82.5
# theta =  -37.5  mean = 0.011831769977875816  sigma =  0.743599411563251
# 0.13791974
# cdf =  0.9995212012177174
# theta =  -17.5  mean = 0.011668598609877017  sigma =  0.7433446857484435
# 0.16874093
# cdf =  0.9998370811583569
# theta =  2.5  mean = 0.011251514280876972  sigma =  0.7363579372492741
# 2.823006
# cdf =  0.9999999999999689
# ...

# %%
#Run code for LSMOD.2 model
tl, tu, ti, var, ntl, ntu = func.define_parameters(2)
name,adtdt,advgpdt,advdmdt,adfdt,n  = func.separate_latitudes_no_time('LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001', tl, tu, ti, var, ntl, ntu)
fig1, fig2, LSMODmuX2, LSMODmax2, LSMODIQR2  = func.plot_figures(adtdt,advgpdt,advdmdt,adfdt,var,n,name)
LSMOD2muXlat, LSMOD2maxlat, LSMOD2IQR, LSMOD2Q1, LSMOD2Q3= func.IQR(adtdt,advgpdt,advdmdt,adfdt,var,n,name)
# Out:
# -77.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-77.5
# -57.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-57.5
# -37.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-37.5
# -17.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-17.5
# 2.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=2.5
# 22.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=22.5
# 42.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=42.5
# 62.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=62.5
# 82.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=82.5
# theta =  -37.5  mean = 0.038763827457995406  sigma =  0.8898631751001278
# 2.4007625
# cdf =  0.9999982301676369
# theta =  -17.5  mean = 0.03746666989049329  sigma =  0.9105453273935973
# 3.1484723
# cdf =  0.9999994322045878
# theta =  2.5  mean = 0.03572829295527306  sigma =  0.8689452278464556
# 2.3308535
# cdf =  0.9999992384550376
# ...

# %%
#Run code for CALS model
tl, tu, ti, var, ntl, ntu = func.define_parameters(2)
name,adtdt,advgpdt,advdmdt,adfdt,n  = func.separate_latitudes_no_time('cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001', tl, tu, ti, var, ntl, ntu)
fig1, fig2, CALSmuX2, CALSmax2, CALSIQR2 = func.plot_figures(adtdt,advgpdt,advdmdt,adfdt,var,n,name)
CALS2muXlat, CALS2maxlat, CALS2IQR, CALS2Q1, CALS2Q3= func.IQR(adtdt,advgpdt,advdmdt,adfdt,var,n, name)
# Out:
# -77.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=-77.5
# -57.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=-57.5
# -37.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=-37.5
# -17.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=-17.5
# 2.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=2.5
# 22.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=22.5
# 42.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=42.5
# 62.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=62.5
# 82.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=82.5
# theta =  -37.5  mean = 0.014557448617340346  sigma =  0.7148801130001147
# 0.058092618
# cdf =  0.9735599731233907
# theta =  -17.5  mean = 0.013870275849787493  sigma =  0.6924098813531189
# 0.053305476
# cdf =  0.9740737003138559
# theta =  2.5  mean = 0.014093822884294423  sigma =  0.6801477286724109
# 0.060608988
# cdf =  0.9840112123706045
# ...

# %%
#Run code for GGF model
tl, tu, ti, var, ntl, ntu = func.define_parameters(3)
name,adtdt,advgpdt,advdmdt,adfdt,n  = func.separate_latitudes_no_time('ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001', tl, tu, ti, var, ntl, ntu)
fig1, fig2, GGFmuX3, GGFmax3, GGFIQR3 = func.plot_figures(adtdt,advgpdt,advdmdt,adfdt,var,n,name)
GGF3muXlat, GGF3maxlat, GGF3IQR, GGF3Q1, GGF3Q3= func.IQR(adtdt,advgpdt,advdmdt,adfdt,var,n, name)
# Out:
# -77.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-77.5
# -57.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-57.5
# -37.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-37.5
# -17.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-17.5
# 2.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=2.5
# 22.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=22.5
# 42.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=42.5
# 62.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=62.5
# 82.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=82.5
# theta =  -37.5  mean = 7.962986471304299  sigma =  1.1279781300030247
# 73.678441
# cdf =  0.9757221676637157
# theta =  -17.5  mean = 7.727339753367649  sigma =  1.122730120373187
# 70.534285
# cdf =  0.9755581396187022
# theta =  2.5  mean = 7.9560276473785985  sigma =  1.131235491481486
# 75.567096
# cdf =  0.976701244868364
# ...

# %%
#Run code for LSMOD.2 model
tl, tu, ti, var, ntl, ntu = func.define_parameters(3)
name,adtdt,advgpdt,advdmdt,adfdt,n  = func.separate_latitudes_no_time('LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001', tl, tu, ti, var, ntl, ntu)
fig1, fig2, LSMODmuX3, LSMODmax3, LSMODIQR3  = func.plot_figures(adtdt,advgpdt,advdmdt,adfdt,var,n,name)
LSMOD3muXlat, LSMOD3maxlat, LSMOD3IQR, LSMOD3Q1, LSMOD3Q3= func.IQR(adtdt,advgpdt,advdmdt,adfdt,var,n,name)
# Out:
# -77.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-77.5
# -57.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-57.5
# -37.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-37.5
# -17.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-17.5
# 2.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=2.5
# 22.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=22.5
# 42.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=42.5
# 62.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=62.5
# 82.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=82.5
# theta =  -37.5  mean = 18.050308702176736  sigma =  1.142432665770535
# 190.0856
# cdf =  0.980338372672204
# theta =  -17.5  mean = 17.991981034535332  sigma =  1.148709291426589
# 224.22849
# cdf =  0.9859594424967059
# theta =  2.5  mean = 17.370858721052617  sigma =  1.1474329288583967
# 191.87017
# cdf =  0.9818428348796188
# ...

# %%
#Run code for CALS model
tl, tu, ti, var, ntl, ntu = func.define_parameters(3)
name,adtdt,advgpdt,advdmdt,adfdt,n  = func.separate_latitudes_no_time('cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001', tl, tu, ti, var, ntl, ntu)
fig1, fig2, CALSmuX3, CALSmax3, CALSIQR3 = func.plot_figures(adtdt,advgpdt,advdmdt,adfdt,var,n,name)
CALS3muXlat, CALS3maxlat, CALS3IQR, CALS3Q1, CALS3Q3= func.IQR(adtdt,advgpdt,advdmdt,adfdt,var,n, name)
# Out:
# -77.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=-77.5
# -57.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=-57.5
# -37.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=-37.5
# -17.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=-17.5
# 2.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=2.5
# 22.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=22.5
# 42.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=42.5
# 62.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=62.5
# 82.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=82.5
# theta =  -37.5  mean = 14.181523737496137  sigma =  1.0760932784529256
# 92.635774
# cdf =  0.9594227840301891
# theta =  -17.5  mean = 14.057634000129186  sigma =  1.1152345095747174
# 78.602852
# cdf =  0.9386319760351222
# theta =  2.5  mean = 14.784258245620098  sigma =  1.0757781265559172
# 99.253948
# cdf =  0.9616357661265881
# ...

# %%
#Run code for GGF model
tl, tu, ti, var, ntl, ntu = func.define_parameters(4)
name,adtdt,advgpdt,advdmdt,adfdt,n  = func.separate_latitudes_no_time('ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001', tl, tu, ti, var, ntl, ntu)
fig1, fig2, GGFmuX4, GGFmax4, GGFIQR4 = func.plot_figures(adtdt,advgpdt,advdmdt,adfdt,var,n,name)
GGF4muXlat, GGF4maxlat, GGF4IQR, GGF4Q1, GGF4Q3= func.IQR(adtdt,advgpdt,advdmdt,adfdt,var,n, name)
# Out:
# -77.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-77.5
# -57.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-57.5
# -37.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-37.5
# -17.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-17.5
# 2.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=2.5
# 22.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=22.5
# 42.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=42.5
# 62.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=62.5
# 82.5 ggf100k_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=82.5
# theta =  -37.5  mean = 0.004696814566544591  sigma =  1.1296575553249526
# 0.047822547
# cdf =  0.9800248343173471
# theta =  -17.5  mean = 0.003760435528435713  sigma =  1.1342989858998358
# 0.039117028
# cdf =  0.9805258038988456
# theta =  2.5  mean = 0.0032533368654047673  sigma =  1.1216283515948628
# 0.029562396
# cdf =  0.9754381348610381
# ...

# %%
#Run code for LSMOD.2 model
tl, tu, ti, var, ntl, ntu = func.define_parameters(4)
name,adtdt,advgpdt,advdmdt,adfdt,n  = func.separate_latitudes_no_time('LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001', tl, tu, ti, var, ntl, ntu)
fig1, fig2, LSMODmuX4, LSMODmax4, LSMODIQR4 = func.plot_figures(adtdt,advgpdt,advdmdt,adfdt,var,n,name)
LSMOD4muXlat, LSMOD4maxlat, LSMOD4IQR, LSMOD4Q1, LSMOD4Q3= func.IQR(adtdt,advgpdt,advdmdt,adfdt,var,n,name)
# Out:
# -77.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-77.5
# -57.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-57.5
# -37.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-37.5
# -17.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=-17.5
# 2.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=2.5
# 22.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=22.5
# 42.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=42.5
# 62.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=62.5
# 82.5 LSMOD.2_tllxyz3_spike_the_alldt_lr=90_type=3_ns=0001_lat=82.5
# theta =  -37.5  mean = 0.010970573063060636  sigma =  1.1325595596961633
# 0.15344057
# cdf =  0.9900790145136057
# theta =  -17.5  mean = 0.008778691651192763  sigma =  1.1517052651565787
# 0.12389489000000001
# cdf =  0.9892311443617694
# theta =  2.5  mean = 0.007650888812621845  sigma =  1.1753083007528144
# 0.15300561
# cdf =  0.9945956419644001
# ...

# %%
#Run code for CALS model
tl, tu, ti, var, ntl, ntu = func.define_parameters(4)
name,adtdt,advgpdt,advdmdt,adfdt,n  = func.separate_latitudes_no_time('cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001', tl, tu, ti, var, ntl, ntu)
fig1, fig2, CALSmuX4, CALSmax4, CALSIQR4 = func.plot_figures(adtdt,advgpdt,advdmdt,adfdt,var,n,name)
CALS4muXlat, CALS4maxlat, CALS4IQR, CALS4Q1, CALS4Q3= func.IQR(adtdt,advgpdt,advdmdt,adfdt,var,n, name)
# Out:
# -77.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=-77.5
# -57.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=-57.5
# -37.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=-37.5
# -17.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=-17.5
# 2.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=2.5
# 22.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=22.5
# 42.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=42.5
# 62.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=62.5
# 82.5 cals10k.2_tllxyz2_spike_the_alldt_lr=90_type=3_ns=0001_lat=82.5
# theta =  -37.5  mean = 0.008406416633418875  sigma =  1.1385501433553935
# 0.053412821
# cdf =  0.9478167892315897
# theta =  -17.5  mean = 0.006854452125128384  sigma =  1.109253278576334
# 0.044688541
# cdf =  0.9545016022247709
# theta =  2.5  mean = 0.005843728636042181  sigma =  1.0670809292550425
# 0.038754120999999996
# ...

# %%
# array of latitudes
lat = np.arange(-77.5,(ntu+1),ti)
label1 = "$\partial \\hat{\\mathbf{B}}/ \partial t$ ($^{\\circ}$ yr$^{-1}$)"
label2 = "$\partial \\hat{\\mathbf{P}}_V/ \partial t$ ($^{\\circ}$ yr$^{-1}$)"
label3 = "$\partial P_V/ \partial t$ ($ZAm^2$ yr$^{-1}$)"
label4 = "$\partial B/ \partial t$ (${\\mu}$T yr$^{-1}$)"

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(15,15))
fig.suptitle('IQR as a Function of Latitude', fontsize=28)
#Subplot 1
ax1.plot(lat, GGF1muXlat, 'x-',color='green')
ax1.plot(lat, LSMOD1muXlat, 'x-',color='red')
ax1.plot(lat, CALS1muXlat, 'x-',color='blue')
ax1.errorbar(lat, GGF1muXlat, xerr=[GGF1Q1 ,GGF1Q3], fmt='k--')
ax1.set_title('IQR ' + str(label1) + ' as a Function of Latitude')
ax1.set_xlabel('Latitude (degrees)')
ax1.set_ylabel(str(label1))

#Subplot 2
ax2.plot(lat, GGF2muXlat, 'x-',color='green')
ax2.plot(lat, LSMOD2muXlat, 'x-',color='red')
ax2.plot(lat, CALS2muXlat, 'x-',color='blue')
ax2.set_title('IQR ' + str(label2) +  ' as a Function of Latitude')
ax2.set_xlabel('Latitude (degrees)')
ax2.set_ylabel(str(label2))

#Subplot 3
ax3.plot(lat, GGF3muXlat, 'x-',color='green')
ax3.plot(lat, LSMOD3muXlat, 'x-',color='red')
ax3.plot(lat, CALS3muXlat, 'x-',color='blue')
ax3.set_title('IQR $\partial P_V/ \partial t$ ($ZAm^2$ yr$^{-1}$) as a Function of Latitude')
ax3.set_xlabel('Latitude (degrees)')
ax3.set_ylabel('IQR $\partial P_V/ \partial t$ ($ZAm^2$ yr$^{-1}$)')

#Subplot 4
ax4.plot(lat, GGF4muXlat, 'x-',color='green')
ax4.plot(lat, LSMOD4muXlat, 'x-',color='red')
ax4.plot(lat, CALS4muXlat, 'x-',color='blue')
ax4.set_title('IQR $\partial B/ \partial t$ (${\\mu}$T yr$^{-1}$) as a Function of Latitude')
ax4.set_xlabel('Latitude (degrees)')
ax4.set_ylabel('IQR $\partial B/ \partial t$ (${\\mu}$T yr$^{-1}$)')
ggf = mpatches.Patch(color='green', label='GGF100k')
lsmod = mpatches.Patch(color='red', label='LSMOD.2')
cals = mpatches.Patch(color='blue', label='CALS10K.2')
plt.legend(handles=[ggf,lsmod, cals], bbox_to_anchor=(1.05,1), borderaxespad=0.)
fig.savefig("IQR_allvar.pdf", format='pdf', bbox_inches='tight',pad_inches = 0.1)

# %%
# array of latitudes
lat = np.arange(-77.5,(ntu+1),ti)
label1 = "$\partial \\hat{\\mathbf{B}}/ \partial t$ ($^{\\circ}$ yr$^{-1}$)"
label2 = "$\partial \\hat{\\mathbf{P}}_V/ \partial t$ ($^{\\circ}$ yr$^{-1}$)"
label3 = "$\partial P_V/ \partial t$ ($ZAm^2$ yr$^{-1}$)"
label4 = "$\partial B/ \partial t$ (${\\mu}$T yr$^{-1}$)"

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(15,15))
fig.suptitle('90th Percentile as a Function of Latitude', fontsize=28)
#Subplot 1
ax1.plot(lat, GGFP901, color='green')
ax1.plot(lat, LSMODP901, color='red')
ax1.plot(lat, CALSP901, color='blue')
ax1.set_title('90th Percentile ' + str(label1) + ' as a Function of Latitude')
ax1.set_xlabel('Latitude (degrees)')
ax1.set_ylabel('90th Percentile' + str(label1))

#Subplot 2
ax2.plot(lat, GGFP902, color='green')
ax2.plot(lat, LSMODP902, color='red')
ax2.plot(lat, CALSP902, color='blue')
ax2.set_title('90th Percentile ' + str(label2) +  ' as a Function of Latitude')
ax2.set_xlabel('Latitude (degrees)')
ax2.set_ylabel('90th Percentile' + str(label2))

#Subplot 3
ax3.plot(lat, GGFP903, color='green')
ax3.plot(lat, LSMODP903, color='red')
ax3.plot(lat, CALSP903, color='blue')
ax3.set_title('90th Percentile $\partial P_V/ \partial t$ ($ZAm^2$ yr$^{-1}$) as a Function of Latitude')
ax3.set_xlabel('Latitude (degrees)')
ax3.set_ylabel('90th Percentile $\partial P_V/ \partial t$ ($ZAm^2$ yr$^{-1}$)')

#Subplot 4
ax4.plot(lat, GGFP904, color='green')
ax4.plot(lat, LSMODP904, color='red')
ax4.plot(lat, CALSP904, color='blue')
ax4.set_title('90th Percentile $\partial B/ \partial t$ (${\\mu}$T yr$^{-1}$) as a Function of Latitude')
ax4.set_xlabel('Latitude (degrees)')
ax4.set_ylabel('90th Percentile $\partial B/ \partial t$ (${\\mu}$T yr$^{-1}$)')
ggf = mpatches.Patch(color='green', label='GGF100k')
lsmod = mpatches.Patch(color='red', label='LSMOD.2')
cals = mpatches.Patch(color='blue', label='CALS10K.2')
plt.legend(handles=[ggf,lsmod, cals], bbox_to_anchor=(1.05,1), borderaxespad=0.)
fig.savefig("P90_allvar.pdf", format='pdf', bbox_inches='tight',pad_inches = 0.1)
